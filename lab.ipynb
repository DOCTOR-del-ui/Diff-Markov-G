# %%
import os
import numpy as np
import pandas as pd

# %%
for idx in range(1, 5):
    for window in [48, 96]:
        data_path = os.path.join("OUTPUT", f"cmapsstmts{idx}_{window}", f"ddpm_fake_cmapsstmts{idx}_{window}.npy")
        data = np.load(data_path)
        print(data.shape)
# Out:
# (15931, 48, 14)
# (11131, 96, 14)
# (12000, 48, 14)
# (12000, 96, 14)
# (20020, 48, 14)
# (15220, 96, 14)
# (12000, 48, 14)
# (12000, 96, 14)

# %%
for idx in range(1, 5):
    for window in [48, 96]:
        data_path = os.path.join("OUTPUT", f"cmapsst{idx}_{window}", "samples", f"cmapsst{idx}_norm_truth_{window}_train.npy")
        data = np.load(data_path)
        print(data.shape)
# Out:
# (15931, 48, 14)
# (11131, 96, 14)
# (41539, 48, 14)
# (29059, 96, 14)
# (20020, 48, 14)
# (15220, 96, 14)
# (49546, 48, 14)
# (37594, 96, 14)

# %%
for idx in range(1, 5):
    for window in [48, 96]:
        data_path = os.path.join("OUTPUT", f"cmapsst{idx}_{window}", f"ddpm_fake_cmapsst{idx}_{window}.npy")
        data = np.load(data_path)
        print(data.shape)
# Out:
# (12800, 48, 14)
# (12800, 96, 14)
# (12800, 48, 14)
# (12800, 96, 14)
# (12800, 48, 14)
# (12800, 96, 14)
# (12800, 48, 14)
# (12800, 96, 14)
